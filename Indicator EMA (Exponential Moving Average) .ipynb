# %% [markdown]
# # Exponential Moving Average (EMA) indicator on SUNPHARMA data ( NSE)

# %% [markdown]
# (from 2019-1-29 to 2019-4-26)

# %%
import numpy as np 
import pandas as pd 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data =  pd.read_csv("SUNPHARMA1.csv",usecols=["Date","Open","High","Low","Close"])
def EMA(df, column="Close", period=14):
    ema = df[column].ewm(span=period, min_periods=period - 1).mean()
    return df.join(ema.to_frame('EMA'))
a=EMA(data)

#@ plotting 

plt.style.use('seaborn')
a['Close'].plot()
a['EMA'].plot()
plt.show()
print( "     \t   Exponential Moving Average (EMA) and Close  \n \n \n  ")
plt.style.use('seaborn')
a['EMA'].plot()
plt.show()
print( "     \n \t  \t  Exponential Moving Average (EMA) \n \n ")
# Out:
#      	   Exponential Moving Average (EMA) and Close
#
#  	  	  Exponential Moving Average (EMA)

# %% [markdown]
# # Al the values OHLC and EMA

# %%
print ( " \n \t \t  Al the values OHLC and EMA")
a
# Out:
#
#  	 	  Al the values OHLC and EMA
#           Date        High         Low        Open       Close         EMA
# 0   2019-01-29  424.750000  406.250000  410.500000  422.399994         NaN
# 1   2019-01-30  426.000000  416.200012  424.000000  417.950012         NaN
# 2   2019-01-31  431.350006  413.700012  419.000000  423.450012         NaN
# 3   2019-02-01  428.000000  417.000000  421.200012  423.250000         NaN
# 4   2019-02-04  423.000000  409.200012  422.299988  414.799988         NaN
# 5   2019-02-05  418.500000  406.549988  414.799988  409.899994         NaN
# 6   2019-02-06  419.000000  403.299988  410.000000  416.600006         NaN
# 7   2019-02-07  445.799988  421.100006  423.000000  434.899994         NaN
# 8   2019-02-08  435.899994  424.500000  434.000000  431.049988         NaN
# 9   2019-02-11  433.600006  420.850006  432.250000  428.549988         NaN
# 10  2019-02-12  444.000000  424.049988  427.200012  436.600006         NaN
# ...
