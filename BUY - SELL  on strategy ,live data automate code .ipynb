# %% [markdown]
# # BUY SELL BOT RSI

# %%
import time
import secrets 
import threading
import logging
import pandas as pd
import numpy as np
import seaborn as sns
from pprint import pprint
import matplotlib.pyplot as plt
from datetime import datetime
from kiteconnect import KiteTicker            
from kiteconnect import KiteConnect  
from IPython.display import clear_output

# %% [markdown]
# # (1) LOGIN TO ZERODHA

# %%
api_key='**********'               
api_secret='***************'

# %% [markdown]
# Generating Link

# %%
kite=KiteConnect(api_key,api_secret)
kite.login_url()
# Out:
# 'https://kite.trade/connect/login?api_key=inx2yhl01h5udgec&v=3'

# %% [markdown]
# # (2) Insert Token

# %%
token="**************"

# %% [markdown]
#  Getting Details and Acess token

# %%
logging.basicConfig(level=logging.DEBUG)
kite = KiteConnect(api_key=api_key)
data = kite.generate_session(token,api_secret)
kite.set_access_token(data["access_token"])
print(data)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /session/token HTTP/1.1" 200 None
# {'user_type': 'company', 'email': 'angelsvirtualworld@gmail.com', 'user_name': 'Angel S Virtual World Private Limited', 'user_shortname': 'Angel', 'broker': 'ZERODHA', 'exchanges': ['CDS', 'MF', 'MCX', 'BSE', 'NSE', 'NFO'], 'products': ['CNC', 'NRML', 'MIS', 'BO', 'CO'], 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'avatar_url': '', 'user_id': 'BQ8330', 'api_key': 'inx2yhl01h5udgec', 'access_token': 'C28KudeSWGvFDiXq5mlyE27RVfFKQtz5', 'public_token': 'Sr7u75iFjKyhie2AM4HgA1yGlZWSBSr1', 'refresh_token': '', 'login_time': datetime.datetime(2019, 5, 24, 9, 57, 35)}

# %% [markdown]
# # (3) Enter  All Inputs for the RSI BOT

# %%
ttradingsymbol="SUNPHARMA"
eexchange     ="NSE" 
ttoken        =857857
RSI_VAL       =50
RSI_VAL2      =51

# %% [markdown]
# #  Flow of Algorithm

# %%
Place an order when RSI is greater then 30
note all candels when rsi comes below 30 and again goes greater then 30
when high of high hits
place BUY SL order  on current high 
if BUY SL order implemented on ZERODHA
place an order of SELL on lowest low which is stored when rsi comes below 30 and goes greater 30
wait-- 
if RSI cross70:
    cancel the SELL SL bit 
    place MARET order of BUY Bit
    and run programe from starting
if sell SL bit executed , run program from starting

# %% [markdown]
# # Flow of program

# %%
# PROGRAM START

# Defining all variables in programe

# MAIN program START
# STARTING PROGRAME Every Minute
# GETTING HISTORCAL DATA

# IMPLEMENTING RSI 

# Interface

#Checking any buy/sell order placed or not

# condition Checking for SELL order

# check which is executed BUY or SELL

# check SL bit is executed or not
# Clearing all Variables and start programe again

# PROGRAME terminates here
# cancel stoploss bid

# Placing Market order
# Clearing all Variables and start programe again

# PROGRAME terminates here

# IF BUy bit EXECUTED in zerodha PLACING SELL order
# SL SELL order Placed 

# SL SELL order Completed 
# APPENDING ALL

# PRINT ALL INFORMAION ABOUT BUY ORDER
# CHECKING CONDITION OF RSI , PROGRAME START CALCULATION FROM HERE
# COMPLETED SUCCESSFULLY AND DATA L.L and RSI IS STORED

# NOW CHECKING CONDITION HIGH 2 HIGH
#CONDITION SATISFYED AND FINDING DATA FOR PACING ORDER

# PLACING ORDER BUY
# EXECUTED SUCCESSFULLY

#APPENDING ALL
# PRINT ALL INFORMAION ABOUT BUY ORDER

# Buy LIMIT order implemented

# %% [markdown]
# # Do not change anything in program from here

# %% [markdown]
# # WebSocket

# %% [markdown]
# Fetching Live Data from websocket

# %%
def websocket():
    logging.basicConfig(level=logging.DEBUG)
    kws = KiteTicker(api_key,token)
    def on_ticks(ws, ticks):
        logging.debug("Ticks: {}".format(ticks))
    def on_connect(ws, response):
        ws.subscribe([256265])
        ws.set_mode(ws.MODE_FULL, [256265])
    def on_close(ws, code, reason):
        ws.stop()
    kws.on_ticks = on_ticks
    kws.on_connect = on_connect
    kws.on_close = on_close
    kws.connect()

# %% [markdown]
# # (4) STRATEGY

# %%
# Defining all variables in programe



a=[0]
b=[0]
hh=[]
ii=[]
ggg=[]
firs=[]
inpu=[]
glkk=[]
akki=[]
check=[]
bii_by=[]
datarsi=[]
orprice=[]
datalow=[]
buyprice=[]
sellorder=[]
org_price=[]
limitprice=[]
sellorder1=[]
orderplaced=[]
sellbit_execute_limit=[]
buy_order_sell_status=[]
buy_order_info_buy_orid=[]
buy_order_info_buy_symbol=[]
buy_order_info_buy_status=[]
buy_order_info_buy_status=[]
buy_order_info_buy_orderid=[]
buy_order_info_sell_orderid=[]


# MAIN program START

def ashi():
    while(True): 
        
        # STARTING PROGRAME Every Minute
        
        km=datetime.now().minute
        ks=datetime.now().second
        
        if km%1==0 and ks==1:
            clear_output(wait=True)
            
            # GETTING HISTORCAL DATA
            
            z=kite.historical_data(ttoken, "2019-01-05", "2019-06-02","minute",0)
            za=pd.DataFrame(z) 
            
            # IMPLEMENTING RSI 
            
            rsi_period=14
            chg=za["close"].diff(1)
            gain=chg.mask(chg<0,0) 
            loss=chg.mask(chg>0,0)
            avg_gain=gain.ewm(com=rsi_period-1,min_periods=rsi_period).mean()
            avg_loss=loss.ewm(com=rsi_period-1,min_periods=rsi_period).mean()
            rs =abs(avg_gain / avg_loss)
            rsi =100 -(100/(1+rs))
            za['rsi']=rsi
            p=za.iloc[-1,6]
            o=za.iloc[-2,2] 
            a.append(p)
            b.append(o)
            
            
            # Interface
               
            
            print(" \n \t \t \t \t  \t Relative Strength Index   ")
            print("\n ")
            print(" Trading symbol is", ttradingsymbol ,"Token is ",ttoken ,"Exchange is ",eexchange, " RSI condition is",RSI_VAL ,RSI_VAL2)
            print("\n ") 
            print("Current RSI status is                  "  , a[-1])
            print("Previous RSI status is                 "  , a[-2])
            print("Current HIGH is                        "  , b[-1])
            print("Previous HIGH satus is                 "  , b[-2])
            
            print("L.L at the time of ENTRY in Condition  "  , datalow)
            for i in datarsi:
                  ggg.append(round(i))
            print("RSI at ENTRY in Condition Rough detail "  , ggg)
            print("\n ")
            print("\t  \t \t   Buy & Sell details and number of order Placed \n ")
            print("\n ")
            print("Orignal Price while placing order is   "  , orprice)
            print("BUY price is                           "  , buyprice)
            print("BUY limit price is                     "  , limitprice)
            print("sell SL trigger price is               "  , sellorder)
            print("sell stoploss is price is              "  , sellorder1)
            print("Number of order placed till now is     "  , len(orderplaced))
            print(" \n \t \t \t \t  Previous RSI and High Status " )
            
            for i in a:
                  hh.append(round(i))
            for i in b:
                  ii.append(round(i))
            print("Previous RSI status is                " , hh[-1])
            
            print("Previous HIGH satus is                " , ii[-1])
           
            
            #Checking any buy/sell order placed or not
          
            if 0 in check:
                
                print(" BUY order Symbol ",buy_order_info_buy_symbol)
                print(" BUY Order Status ",buy_order_info_buy_status)
                print(" BUY Order id     ",buy_order_info_buy_orid)
                print(" BUY Order of ", buy_order_info_buy_symbol, "is Completed on zerodha and order id  is", buy_order_info_buy_orid)
                        
            
            if 0 in sellbit_execute_limit:
                
                print(" SELL order Status", buy_order_sell_status)
                print(" SELL order id ",buy_order_info_sell_orderid)
                print(" SELL Order of ",buy_order_sell_status, "is Completed on zerodha and order id  is", buy_order_info_sell_orderid)
                

                
            # condition Checking for SELL order

            if 0 in check: 
                
                # (buy bit worked )
                
                
                if 0 in sellbit_execute_limit:
                    
                    # check which is executed BUY or SELL
                    
                    # check SL bit is executed or not
                    
                    mno2=kite.orders()
                    pqr2=pd.DataFrame(mno2)
                    stu2=pqr2[["tradingsymbol","status","exchange_order_id"]].tail(2)
                    
                    # Checking condition SL bit executed or not in Zerodha 
                    
                    if "COMPLETE" in stu2.iloc[-1,1] and ttradingsymbol in stu2.iloc[-1,2]:
                        
                        print("yes order already executed of SL ")
                        
                        # Clearing all Variables and start programe again
                        
                        glkk.clear()
                        akki.clear()
                        a.clear()
                        b.clear()
                        hh.clear()
                        ii.clear()
                        ggg.clear()
                        inpu.clear()
                        firs.clear()
                        check.clear()
                        bii_by.clear()
                        datarsi.clear()
                        orprice.clear()
                        buyprice.clear()
                        sellorder.clear()
                        datalow.clear()
                        org_price.clear()
                        limitprice.clear()
                        sellorder1.clear()
                        orderplaced.clear()
                        sellbit_execute_limit.clear()
                        buy_order_sell_status.clear()
                        buy_order_info_buy_orid.clear()
                        buy_order_info_buy_symbol.clear()
                        buy_order_info_buy_status.clear()
                        buy_order_info_buy_status.clear()
                        buy_order_info_buy_orderid.clear()
                        buy_order_info_sell_orderid.clear()
                        ashi()
                        
                        
                        
                    if za.iloc[-1,6]>=60:
                        
                        # cancel stoploss bid
                        
                        kite.cancel_order("regular",buy_order_info_sell_orderid, parent_order_id=None)
                        print("SL order Cancel id is : ",buy_order_info_sell_orderid)
                        
                        # Placing Market order
                        
                        kite.place_order(variety="regular",tradingsymbol=ttradingsymbol,quantity=1,exchange=eexchange,order_type='MARKET',transaction_type='SELL',product='CNC',tag="abtSEM")
                        print("Market order place and Bot starts again")
                        
                        
                        # Clearing all Variables and start programe again
                        
                        glkk.clear()
                        a.clear()
                        b.clear()
                        hh.clear()
                        ii.clear()
                        akki.clear()
                        ggg.clear()
                        inpu.clear()
                        firs.clear()
                        check.clear()
                        bii_by.clear()
                        datarsi.clear()
                        orprice.clear()
                        buyprice.clear()
                        sellorder.clear()
                        datalow.clear()
                        org_price.clear()
                        limitprice.clear()
                        sellorder1.clear()
                        orderplaced.clear()
                        sellbit_execute_limit.clear()
                        buy_order_sell_status.clear()
                        buy_order_info_buy_orid.clear()
                        buy_order_info_buy_symbol.clear()
                        buy_order_info_buy_status.clear()
                        buy_order_info_buy_status.clear()
                        buy_order_info_buy_orderid.clear()
                        buy_order_info_sell_orderid.clear()
                        ashi()
                        
                    else:
                        pass
                                     
                                ############ PROGRAME END HERE ############
                        
                        
                        
                if 0 not in glkk:  
                    
                    # IF BUy bit EXECUTED in zerodha PLACING SELL order
                    
                    z0=kite.orders()
                    kk0=pd.DataFrame(z0)
                    zp0=kk0[["tradingsymbol","status","exchange_order_id"]].tail(2)
                    zz0=pd.DataFrame(zp0)
                    
                    if ttradingsymbol in zz0.iloc[-1,0] and "COMPLETE" in zz0.iloc[-1,1]:
                        triggerpriceis=min(datalow)
                        sellorder.append(triggerpriceis)
                        stoplossis=triggerpriceis-5
                        sellorder1.append(stoplossis)
                        clear_output(wait=True)
                        
                        # SL SELL order Placed 
                        
                        print("Buy Order of ", buy_order_info_buy_symbol, "is Completed on zerodha and order id  is", buy_order_info_buy_orid )
                        print("Buy Limit order placed and Price is ", limitprice , " and Triger price is ", buyprice )        
                        print(" Sell Stoploss order placed and SL trigger price is  ", triggerpriceis, " and stoploss is",stoplossis)
                        
                        kite.place_order(variety="regular",tradingsymbol=ttradingsymbol,quantity=1,exchange=eexchange,order_type='SL',trigger_price= triggerpriceis,stoploss= stoplossis,transaction_type='SELL',product='CNC',tag="abtSEL")

                        # SL SELL order Completed 
                        
                        #
                        
                        z1=kite.orders()
                        kk1=pd.DataFrame(z1)
                        zp1=kk1[[ "exchange_order_id","status","tradingsymbol","exchange_timestamp"]].tail(1)
                        
                        # APPENDING ALL
                        
                        zz1=pd.DataFrame(zp1)
                        listt1=zz1.iloc[-1,0]
                        listtt2=zz1.iloc[-1,1]
                        buy_order_sell_status.append(listtt2)
                        zkak=int(listt1)
                        buy_order_info_sell_orderid.append(zkak)
                        
                        # PRINT ALL INFORMAION ABOUT BUY ORDER
                        
                        print(buy_order_sell_status)
                        print(buy_order_info_sell_orderid)
                        sellbit_execute=secrets.randbelow(1)
                        sellbit_execute_limit.append(sellbit_execute)
                        glk=secrets.randbelow(1)
                        glkk.append(glk)
                        
                    else:
                        pass    
                else:
                    pass

            # CHECKING CONDITION OF RSI , PROGRAME START CALCULATION FROM HERE
                
            if 0 in bii_by:
                
                if 0 not in akki:
                    
                    if za.iloc[-2,2] <  za.iloc[-1,2]:

                        #CONDITION SATISFYED AND FINDING DATA FOR PACING ORDER
                        
                        orgprice=za.iloc[-1,2]
                        orprice.append(orgprice)
                        cur_high=za.iloc[-1,2] + 1 
                        lim_price=cur_high+3
                        buyprice.append(cur_high) 
                        limitprice.append(lim_price)
                        org_price.append(orgprice) 


                        # PLACING ORDER BUY

                        print("Congrats ! One Limit Buy Order placed Price is",  lim_price , "and trigger_price is ", cur_high)
                        kite.place_order( variety="regular",tradingsymbol=ttradingsymbol,quantity=1,exchange=eexchange,order_type='SL',price=lim_price ,trigger_price=cur_high,transaction_type='BUY',product='CNC',tag="abtBYL")

                        # EXECUTED SUCCESSFULLY

                        z=kite.orders()
                        kk=pd.DataFrame(z)
                        zp=kk[["tradingsymbol","status","exchange_order_id"]].tail(2)
                        zz=pd.DataFrame(zp)
                        list_buy_symbol=zz.iloc[-1,0]
                        list_buy_status=zz.iloc[-1,1]
                        orid=zz.iloc[-1,2]  

                        #APPENDING ALL

                        buy_order_info_buy_symbol.append(list_buy_symbol)
                        buy_order_info_buy_status.append(list_buy_status)
                        buy_order_info_buy_orid.append(orid)

                        # PRINT ALL INFORMAION ABOUT BUY ORDER

                        print(" BUY ORDER SYMBOL ",buy_order_info_buy_symbol)
                        print(" BUY ORDER STATUS ",buy_order_info_buy_status)
                        print("BUY ORDER ID IS ",buy_order_info_buy_orid)
                        
                        # Appending in variables
                        
                        biiiii = secrets.randbelow(1)
                        akki.append(biiiii)
                        p = secrets.randbelow(1)
                        check.append(p)
                        
                    else:
                        pass
                    
                    # Buy LIMIT order implemented
                
                else:
                    pass
                
            if 0 not in bii_by:
                
                if 2 not in firs:
                    
                    if za.iloc[-2,6]>= RSI_VAL  and za.iloc[-1,6]<=RSI_VAL:
                        fiss=2
                        apa=1
                        firs.append(fiss)
                        inpu.append(apa)
                        
                    else:
                        pass
                    
                if 1 in inpu:
                    
                    # Appending data when enter in condition of RSI
                    
                    datalow.append(za.iloc[-1,3])
                    datarsi.append(za.iloc[-1,6])
                    
                    # Stop Calculatigng RSI condition
                    
                    if za.iloc[-1,6]>=RSI_VAL2:
                        
                        # finding low 
                        
                        bii = secrets.randbelow(1)
                        bii_by.append(bii)
                        
                    else:
                        pass
                else:
                    pass
            else:
                pass
ashi()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments/historical/857857/minute?instrument_token=857857&from=2019-01-05&to=2019-06-02&interval=minute&continuous=0 HTTP/1.1" 200 None
#
#  	 	 	 	  	 Relative Strength Index
#
#
#  Trading symbol is SUNPHARMA Token is  857857 Exchange is  NSE  RSI condition is 50 51
#
#
# Current RSI status is                   49.45032311038635
# Previous RSI status is                  49.45032311038635
# Current HIGH is                         415.75
# Previous HIGH satus is                  415.75
# L.L at the time of ENTRY in Condition   []
# RSI at ENTRY in Condition Rough detail  []
#
#
# 	  	 	   Buy & Sell details and number of order Placed
#
#
#
# Orignal Price while placing order is    []
# BUY price is                            []
# BUY limit price is                      []
# sell SL trigger price is                []
# sell stoploss is price is               []
# Number of order placed till now is      0
#
#  	 	 	 	  Previous RSI and High Status
# Previous RSI status is                 49.0
# Previous HIGH satus is                 416.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d7403e375f33> in <module>
#     380             else:
#     381                 pass
# --> 382 ashi()
#
# <ipython-input-8-d7403e375f33> in ashi()
#      38         # STARTING PROGRAME Every Minute
#      39
# ---> 40         km=datetime.now().minute
#      41         ks=datetime.now().second
#      42
#
# KeyboardInterrupt:
