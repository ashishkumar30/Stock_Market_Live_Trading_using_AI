# %%
from kiteconnect import KiteTicker               
from kiteconnect import KiteConnect  
api_key='*************'                      
api_secret='************'   
kite=KiteConnect(api_key,api_secret)
kite.login_url()

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
kite = KiteConnect(api_key=api_key)
token="39aA1wm2nfNa5aweX7OXX4GDsTjrQR2B"
data = kite.generate_session(token,api_secret)
kite.set_access_token(data["access_token"])
print(data)

# %%
from pprint import pprint
import pandas as pd
import numpy as np
k=kite.instruments(exchange=None)
z=pd.DataFrame(k)
z.to_csv("tokenlist.csv")
z
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments HTTP/1.1" 200 5039621
#        instrument_token exchange_token tradingsymbol  \
# 0             130820612         511018      ZMILGFIN
# 1             249018372         972728    YES28MAR12
# 2             138919428         542654       VRFILMS
# 3             242695172         948028   UPL08JUN12B
# 4             242694916         948027   UPL08JUN12A
# 5             135994372         531228        RANDER
# 6             135916804         530925       RAMSONS
# 7             135923460         530951       RAMINFO
# 8             131641092         514223     RAMGOPOLY
# 9             136286724         532370      RAMCOSYS
# 10            136105732         531663    YUVRAAJHPL
# 11            134790404         526525       WWLEATH
# 12            138304516         540252           VSL
# 13            136589572         533553    TDPOWERSYS
# 14            132121092         516098       VENTURA
# 15            130942212         511493        VCKCAP
# 16            136286468         532369      RAMCOIND
# 17            128066564         500260      RAMCOCEM
# 18            133961988         523289    RAMAVISION
# 19            138063108         539309     RAMASTEEL
# 20            131872516         515127     RAMASIGNS
# 21            131620868         514144      UNIWORTH
# 22            131088388         512064        VISVEN
# 23            131127044         512215   STEPHANOTIS
# 24            128662276         502587      RAMAPULP
# 25            128091396         500357     RAMAPPR-B
# 26            134153476         524037       RAMAPHO
# 27            128090884         500355        RALLIS
# 28            134680324         526095       RALEGRA
# 29            136362244         532665        RAJVIR
# ...                 ...            ...           ...
# 64389           2054913           8027  726GS2029-GS
# 64390           1845249           7208  717GS2028-GS
# 64391           1800961           7035  716GS2023-GS
# 64392           1839105           7184  706GS2046-GS
# 64393           2066945           8074  700GS2021-GS
# 64394           1786625           6979   69GS2019-GS
# 64395           1832449           7158  697GS2026-GS
# 64396           1833217           7161  684GS2022-GS
# 64397           1775361           6935  683GS2039-GS
# 64398            945409           3693       GAYAHWS
# 64399           1045249           4083  AMBANIORG-SM
# 64400           1823233           7122  788GS2030-GS
# 64401           5181953          20242    OBEROIRLTY
# 64402           2762497          10791       NUCLEUS
# 64403           2752257          10751       NTPC-ND
# 64404           2751745          10749       NTPC-NC
# 64405           2750977          10746       NTPC-NB
# 64406           2750465          10744       NTPC-NA
# 64407           2749697          10741       NTPC-N9
# 64408           2748673          10737       NTPC-N8
# 64409           1888513           7377       NTPC-N7
# 64410           3730433          14572      GLOBOFFS
# 64411           5052929          19738     GLOBAL-SM
# 64412           1895937           7406      GLENMARK
# 64413            295169           1153         GLAXO
# 64414           1225217           4786        AKG-SM
# 64415           6953217          27161      CINELINE
# 64416           6447105          25184        CIMMCO
# 64417           1316353           5142    CIGNITITEC
# 64418            175361            685      CHOLAFIN
#
#                             name  last_price expiry  strike  tick_size  \
# 0                                        0.0            0.0       0.05
# 1      YESBANK-9.90%-28-3-22-PVT         0.0            0.0       0.01
# 2                                        0.0            0.0       0.05
# 3                                        0.0            0.0       0.01
# 4                                        0.0            0.0       0.01
# 5             RANDER CORPORATION         0.0            0.0       0.01
# 6               RAMSONS PROJECTS         0.0            0.0       0.01
# 7                        RAMINFO         0.0            0.0       0.05
# 8               RAMGOPAL POLYTEX         0.0            0.0       0.01
# 9                  RAMCO SYSTEMS         0.0            0.0       0.05
# 10                                       0.0            0.0       0.01
# 11                                       0.0            0.0       0.01
# 12                                       0.0            0.0       0.05
# 13                                       0.0            0.0       0.05
# 14                                       0.0            0.0       0.01
# 15                                       0.0            0.0       0.01
# 16              RAMCO INDUSTRIES         0.0            0.0       0.05
# 17             THE RAMCO CEMENTS         0.0            0.0       0.05
# 18                   RAMA VISION         0.0            0.0       0.01
# 19              RAMA STEEL TUBES         0.0            0.0       0.05
# 20          RAMASIGNS INDUSTRIES         0.0            0.0       0.01
# 21                                       0.0            0.0       0.01
# 22                                       0.0            0.0       0.05
# 23                                       0.0            0.0       0.05
# 24            RAMA PULP & PAPERS         0.0            0.0       0.05
# 25              RAMA PAPER MILLS         0.0            0.0       0.05
# 26               RAMA PHOSPHATES         0.0            0.0       0.05
# 27                  RALLIS INDIA         0.0            0.0       0.05
# 28            RAVILEELA GRANITES         0.0            0.0       0.01
# 29             RAJVIR INDUSTRIES         0.0            0.0       0.01
# ...                          ...         ...    ...     ...        ...
# 64389                                    0.0            0.0       0.01
# 64390                                    0.0            0.0       0.01
# 64391                                    0.0            0.0       0.01
# 64392                                    0.0            0.0       0.01
# 64393                                    0.0            0.0       0.01
# 64394                                    0.0            0.0       0.01
# 64395                                    0.0            0.0       0.01
# 64396                                    0.0            0.0       0.01
# 64397                                    0.0            0.0       0.01
# 64398                                    0.0            0.0       0.05
# 64399                                    0.0            0.0       0.05
# 64400                                    0.0            0.0       0.01
# 64401              OBEROI REALTY         0.0            0.0       0.05
# 64402   NUCLEUS SOFTWARE EXPORTS         0.0            0.0       0.05
# 64403      TFB 7.62% 2035 SR. 3B         0.0            0.0       0.01
# 64404      TFB 7.53% 2030 SR. 2B         0.0            0.0       0.01
# 64405      TFB 7.36% 2025 SR. 1B         0.0            0.0       0.01
# 64406      TFB 7.37% 2035 SR. 3A         0.0            0.0       0.01
# 64407      TFB 7.28% 2030 SR. 2A         0.0            0.0       0.01
# 64408      TFB 7.11% 2025 SR. 1A         0.0            0.0       0.01
# 64409  8.49% SEC NON-CUM RED NCD         0.0            0.0       0.01
# 64410                                    0.0            0.0       0.05
# 64411           GLOBAL EDUCATION         0.0            0.0       0.05
# 64412   GLENMARK PHARMACEUTICALS         0.0            0.0       0.05
# 64413  GLAXOSMITHKLINE PHARMA LT         0.0            0.0       0.05
# 64414                                    0.0            0.0       0.05
# 64415             CINELINE INDIA         0.0            0.0       0.05
# 64416                     CIMMCO         0.0            0.0       0.05
# 64417                                    0.0            0.0       0.05
# 64418  CHOLAMANDALAM IN & FIN CO         0.0            0.0       0.05
#
#        lot_size instrument_type segment exchange
# 0            50              EQ     BSE      BSE
# 1             1              EQ     BSE      BSE
# 2          2000              EQ     BSE      BSE
# 3             1              EQ     BSE      BSE
# 4             1              EQ     BSE      BSE
# 5             1              EQ     BSE      BSE
# 6             1              EQ     BSE      BSE
# 7             1              EQ     BSE      BSE
# 8             1              EQ     BSE      BSE
# 9             1              EQ     BSE      BSE
# 10            1              EQ     BSE      BSE
# 11            1              EQ     BSE      BSE
# 12         1500              EQ     BSE      BSE
# 13            1              EQ     BSE      BSE
# 14            1              EQ     BSE      BSE
# 15            1              EQ     BSE      BSE
# 16            1              EQ     BSE      BSE
# 17            1              EQ     BSE      BSE
# 18            1              EQ     BSE      BSE
# 19            1              EQ     BSE      BSE
# 20            1              EQ     BSE      BSE
# 21            1              EQ     BSE      BSE
# 22            1              EQ     BSE      BSE
# 23            1              EQ     BSE      BSE
# 24            1              EQ     BSE      BSE
# 25            1              EQ     BSE      BSE
# 26            1              EQ     BSE      BSE
# 27            1              EQ     BSE      BSE
# 28            1              EQ     BSE      BSE
# 29            1              EQ     BSE      BSE
# ...         ...             ...     ...      ...
# 64389         1              EQ     NSE      NSE
# 64390         1              EQ     NSE      NSE
# 64391         1              EQ     NSE      NSE
# 64392         1              EQ     NSE      NSE
# 64393         1              EQ     NSE      NSE
# 64394         1              EQ     NSE      NSE
# 64395         1              EQ     NSE      NSE
# 64396         1              EQ     NSE      NSE
# 64397         1              EQ     NSE      NSE
# 64398         1              EQ     NSE      NSE
# 64399      2000              EQ     NSE      NSE
# 64400         1              EQ     NSE      NSE
# 64401         1              EQ     NSE      NSE
# 64402         1              EQ     NSE      NSE
# 64403         1              EQ     NSE      NSE
# 64404         1              EQ     NSE      NSE
# 64405         1              EQ     NSE      NSE
# 64406         1              EQ     NSE      NSE
# 64407         1              EQ     NSE      NSE
# 64408         1              EQ     NSE      NSE
# 64409         1              EQ     NSE      NSE
# 64410         1              EQ     NSE      NSE
# 64411      1000              EQ     NSE      NSE
# 64412         1              EQ     NSE      NSE
# 64413         1              EQ     NSE      NSE
# 64414      4000              EQ     NSE      NSE
# 64415         1              EQ     NSE      NSE
# 64416         1              EQ     NSE      NSE
# 64417         1              EQ     NSE      NSE
# 64418         1              EQ     NSE      NSE
#
# [64419 rows x 12 columns]
